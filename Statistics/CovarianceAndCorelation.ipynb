# %%
import numpy as np

# sample data
x = np.array([10, 12, 13, 16, 18, 20])
y = np.array([15, 18, 17, 22, 24, 27])

# covariance matrix
cov_matrix = np.cov(x, y)

print("Covariance matrix:\n", cov_matrix)

# covariance value (off-diagonal)
cov_xy = cov_matrix[0, 1]
print("Covariance (x,y):", cov_xy)
# Out:
# Covariance matrix:
#  [[14.56666667 17.3       ]
#  [17.3        21.1       ]]
# Covariance (x,y): 17.3

# %%
import numpy as np

x = np.array([10, 12, 13, 16, 18, 20])
y = np.array([15, 18, 17, 22, 24, 27])

# correlation coefficient
corr_matrix = np.corrcoef(x, y)

print("Correlation matrix:\n", corr_matrix)

corr_xy = corr_matrix[0, 1]
print("Correlation (x,y):", corr_xy)
# Out:
# Correlation matrix:
#  [[1.        0.9867901]
#  [0.9867901 1.       ]]
# Correlation (x,y): 0.9867901013334656

# %%
from scipy.stats import pearsonr

corr, p_value = pearsonr(x, y)

print("Correlation:", corr)
print("p-value:", p_value)
# Out:
# Correlation: 0.9867901013334656
# p-value: 0.0002605995611141124
